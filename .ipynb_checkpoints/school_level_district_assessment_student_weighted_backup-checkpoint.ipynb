# %%
#################################### Formats Excel Spreadsheet ################################

# %%
import numpy as np
import pandas as pd

# %%
# loads the surveys as dataframes

df2016 = pd.read_excel('accountability2016schools.xlsx')
df2012 = pd.read_excel('accountability2012schools.xlsx')

# %%
dfstudentcount2016 = pd.read_excel('class_size2016.xlsx')
dfstudentcount2012 = pd.read_excel('class_size2012.xlsx')

# overrides school name of dfstudentounts withdf 201x
del dfstudentcount2012['school']
del dfstudentcount2016['school']
print(len(dfstudentcount2012), len(df2012))
# Out:
# 1848 1828

# %%
# removes all rows where level is marked insufficient data

df2012 = df2012[df2012.level_2012 != 'Insufficient data']
df2012 = df2012[df2012.level_2012 != '']
print(len(df2012))

df2016 = df2016[df2016.level_2016 != 'Insufficient data']
df2016 = df2016[df2016.level_2016 != '']

print(len(df2016))
# Out:
# 1586
# 1621

# %%
df2016_merged = df2016.merge(dfstudentcount2016, on='org_code')

print(len(df2016))

df2012 = df2012.merge(dfstudentcount2012, on='org_code')

print(len(df2012))

# creates new row of just districts
def get_district(value):
    index = value.index(' -')
    if value[: index+1] not in districtlst:
        return value[: index+1]

# creates new row of just schools
def get_school(value): 
    index = value.index(' -') 
    return value[index + 3:]

df2012[:5]
# Out:
# 1621
# 1572
#                                               school  org_code level_2012  \
# 0  Abby Kelley Foster Charter Public (District) -...   4450105    Level 1
# 1                           Abington - Abington High     10505    Level 2
# 2                    Abington - Frolio Middle School     10405    Level 2
# 3             Abington - Woodsdale Elementary School     10015    Level 1
# 4  Academy Of the Pacific Rim Charter Public (Dis...   4120530    Level 1
#
#                   school_type  student_count
# 0  Middle-High School or K-12           1426
# 1                 High School            498
# 2               Middle School            346
# 3           Elementary School            315
# 4  Middle-High School or K-12            493

# %%
df2012['level_2012'] = df2012['level_2012'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])
df2016['level_2016'] = df2016['level_2016'].apply(lambda x: [int(x) for x in x.split() if x.isdigit()][0])

# creates row of districts
df2012['district'] = df2012['school'].apply(lambda x: get_district(x))
df2016['district'] = df2016['school'].apply(lambda x: get_district(x))

# creates row of schools
df2012['school'] = df2012['school'].apply(lambda x: get_school(x))
df2016['school'] = df2016['school'].apply(lambda x: get_school(x))

# %%
dfmerged = df2016.merge(df2012, on='org_code')

del dfmerged['school_y']
del dfmerged['school_type_y']
del dfmerged['district_y']

# %%
def weighted_score():
    score_lst = []
    for index, row in dfmerged.iterrows():
        score = (row['level_2012'] - row['level_2016']) * row['student_count']
        score_lst.append(score)
    return score_lst

dfmerged['score'] = weighted_score()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\j\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2433             try:
# -> 2434                 return libts.get_value_box(s, key)
#    2435             except IndexError:
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18843)()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.get_value_box (pandas\_libs\tslib.c:18477)()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-217-d06368a3edcf> in <module>()
#       6     return score_lst
#       7
# ----> 8 dfmerged['score'] = weighted_score()
#
# <ipython-input-217-d06368a3edcf> in weighted_score()
#       2     score_lst = []
#       3     for index, row in dfmerged.iterrows():
# ----> 4         score = (row['level_2012'] - row['level_2016']) * row['student_count']
#       5         score_lst.append(score)
#       6     return score_lst
#
# C:\Users\j\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# C:\Users\j\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2440                     raise InvalidIndexError(key)
#    2441                 else:
# -> 2442                     raise e1
#    2443             except Exception:  # pragma: no cover
#    2444                 raise e1
#
# C:\Users\j\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    2426         try:
#    2427             return self._engine.get_value(s, k,
# -> 2428                                           tz=getattr(series.dtype, 'tz', None))
#    2429         except KeyError as e1:
#    2430             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value (pandas\_libs\index.c:4363)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value (pandas\_libs\index.c:4046)()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas\_libs\index.c:5085)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20405)()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas\_libs\hashtable.c:20359)()
#
# KeyError: 'student_count'

# %%
dfmerged
# Out:
#                                               school_x  org_code  level_2016  \
# 0             Abby Kelley Foster Charter Public School   4450105           2
# 1                                        Abington High     10505           1
# 2                                 Frolio Middle School     10405           2
# 3                          Woodsdale Elementary School     10015           2
# 4     Academy Of the Pacific Rim Charter Public School   4120530           2
# 5                       Acton-Boxborough Regional High   6000505           1
# 6                           Raymond J Grey Junior High   6000405           1
# 7                           Acushnet Elementary School     30025           2
# 8                          Albert F Ford Middle School     30305           2
# 9                                  Cheshire Elementary   6030004           2
# 10                  Hoosac Valley Middle & High School   6030505           3
# 11                                 Plunkett Elementary   6030020           3
# 12    Advanced Math and Science Academy Charter School   4300305           2
# 13                                         Agawam High     50505           2
# 14                                  Agawam Junior High     50405           2
# 15                                   Benjamin J Phelps     50020           2
# 16                                  Clifford M Granger     50010           2
# 17                                  James Clark School     50030           2
# 18                           Roberta G. Doering School     50303           2
# 19                                       Robinson Park     50025           2
# 20                                 Amesbury Elementary     70005           2
# 21                                       Amesbury High     70505           2
# 22                                     Amesbury Middle     70013           2
# 23                        Charles C Cashman Elementary     70010           2
# 24                             Crocker Farm Elementary     80009           2
# 25                               Fort River Elementary     80020           2
# 26                                 Wildwood Elementary     80050           2
# 27                               Amherst Regional High   6050505           2
# 28                      Amherst Regional Middle School   6050405           3
# 29                                        Andover High     90505           2
# ...                                                ...       ...         ...
# 1486                                        Gates Lane   3480110           2
# 1487                  Goddard School/Science Technical   3480100           3
# 1488                                    Grafton Street   3480115           3
# 1489                                      Heard Street   3480136           2
# 1490                                Jacob Hiatt Magnet   3480140           2
# 1491                                         Lake View   3480145           1
# 1492                                    Lincoln Street   3480160           3
# 1493                                        May Street   3480175           2
# 1494                                    Midland Street   3480185           1
# 1495                                      Nelson Place   3480200           2
# 1496                                   Norrback Avenue   3480202           1
# 1497                                        North High   3480515           3
# 1498                                      Quinsigamond   3480210           3
# 1499                                       Rice Square   3480215           3
# 1500                                         Roosevelt   3480220           1
# 1501                              South High Community   3480520           3
# 1502                                   Sullivan Middle   3480423           3
# 1503                                           Tatnuck   3480230           2
# 1504                                    Thorndyke Road   3480235           1
# 1505                                 Union Hill School   3480240           3
# 1506                       University Pk Campus School   3480285           2
# 1507                                Vernon Hill School   3480280           3
# 1508                               Wawecus Road School   3480026           2
# 1509                                      West Tatnuck   3480260           1
# 1510                                  Woodland Academy   3480030           3
# 1511                      Worcester Arts Magnet School   3480225           1
# 1512                             Worcester East Middle   3480420           3
# 1513                          Worcester Technical High   3480605           1
# 1514                                Charles E Roderick   3500010           2
# 1515                                           Delaney   3500003           1
#
#                    school_type_x  \
# 0     Middle-High School or K-12
# 1                    High School
# 2                  Middle School
# 3              Elementary School
# 4     Middle-High School or K-12
# 5                    High School
# 6                  Middle School
# 7              Elementary School
# 8                  Middle School
# 9              Elementary School
# 10    Middle-High School or K-12
# 11             Elementary School
# 12    Middle-High School or K-12
# 13                   High School
# 14                 Middle School
# 15             Elementary School
# 16             Elementary School
# 17             Elementary School
# 18                 Middle School
# 19             Elementary School
# 20             Elementary School
# 21                   High School
# 22                 Middle School
# 23             Elementary School
# 24             Elementary School
# 25             Elementary School
# 26             Elementary School
# 27                   High School
# 28                 Middle School
# 29                   High School
# ...                          ...
# 1486           Elementary School
# 1487           Elementary School
# 1488           Elementary School
# 1489           Elementary School
# 1490           Elementary School
# 1491           Elementary School
# 1492           Elementary School
# 1493           Elementary School
# 1494           Elementary School
# 1495           Elementary School
# 1496           Elementary School
# 1497                 High School
# 1498           Elementary School
# 1499           Elementary School
# 1500           Elementary School
# 1501                 High School
# 1502               Middle School
# 1503           Elementary School
# 1504           Elementary School
# 1505           Elementary School
# 1506  Middle-High School or K-12
# 1507           Elementary School
# 1508           Elementary School
# 1509           Elementary School
# 1510           Elementary School
# 1511           Elementary School
# 1512               Middle School
# 1513                 High School
# 1514           Elementary School
# 1515           Elementary School
#
#                                              district_x  level_2012  \
# 0         Abby Kelley Foster Charter Public (District)            1
# 1                                             Abington            2
# 2                                             Abington            2
# 3                                             Abington            1
# 4     Academy Of the Pacific Rim Charter Public (Dis...           1
# 5                                     Acton-Boxborough            1
# 6                                     Acton-Boxborough            2
# 7                                             Acushnet            1
# 8                                             Acushnet            2
# 9                                       Adams-Cheshire            2
# 10                                      Adams-Cheshire            2
# 11                                      Adams-Cheshire            3
# 12    Advanced Math and Science Academy Charter (Dis...           1
# 13                                              Agawam            1
# 14                                              Agawam            2
# 15                                              Agawam            2
# 16                                              Agawam            1
# 17                                              Agawam            2
# 18                                              Agawam            2
# 19                                              Agawam            2
# 20                                            Amesbury            1
# 21                                            Amesbury            1
# 22                                            Amesbury            2
# 23                                            Amesbury            1
# 24                                             Amherst            2
# 25                                             Amherst            2
# 26                                             Amherst            2
# 27                                      Amherst-Pelham            3
# 28                                      Amherst-Pelham            2
# 29                                             Andover            1
# ...                                                 ...         ...
# 1486                                         Worcester            2
# 1487                                         Worcester            3
# 1488                                         Worcester            3
# 1489                                         Worcester            1
# 1490                                         Worcester            2
# 1491                                         Worcester            2
# 1492                                         Worcester            3
# 1493                                         Worcester            2
# 1494                                         Worcester            2
# 1495                                         Worcester            1
# 1496                                         Worcester            3
# 1497                                         Worcester            3
# 1498                                         Worcester            3
# 1499                                         Worcester            3
# 1500                                         Worcester            3
# 1501                                         Worcester            3
# 1502                                         Worcester            3
# 1503                                         Worcester            2
# 1504                                         Worcester            2
# 1505                                         Worcester            4
# 1506                                         Worcester            1
# 1507                                         Worcester            3
# 1508                                         Worcester            2
# 1509                                         Worcester            1
# 1510                                         Worcester            3
# 1511                                         Worcester            1
# 1512                                         Worcester            2
# 1513                                         Worcester            1
# 1514                                          Wrentham            2
# 1515                                          Wrentham            2
#
#       student_count  score
# 0              1426  -1426
# 1               498    498
# 2               346      0
# 3               315   -315
# 4               493   -493
# 5              1989      0
# 6               939    939
# 7               540   -540
# 8               463      0
# 9               179      0
# 10              751   -751
# 11              552      0
# 12              969   -969
# 13             1303  -1303
# 14              647      0
# 15              366      0
# 16              304   -304
# 17              364      0
# 18              610      0
# 19              388      0
# 20              427   -427
# 21              639   -639
# 22              738      0
# 23              547   -547
# 24              403      0
# 25              385      0
# 26              438      0
# 27             1077   1077
# 28              482   -482
# 29             1794  -1794
# ...             ...    ...
# 1486            700      0
# 1487            622      0
# 1488            384      0
# 1489            264   -264
# 1490            454      0
# 1491            314    314
# 1492            250      0
# 1493            310      0
# 1494            226    226
# 1495            501   -501
# 1496            621   1242
# 1497           1146      0
# 1498            737      0
# 1499            403      0
# 1500            725   1450
# 1501           1183      0
# 1502            907      0
# 1503            436      0
# 1504            340    340
# 1505            493    493
# 1506            246   -246
# 1507            505      0
# 1508            151      0
# 1509            362      0
# 1510            543      0
# 1511            384      0
# 1512            654   -654
# 1513           1312      0
# 1514            484      0
# 1515            691    691
#
# [1516 rows x 8 columns]

# %%
districtlst = []
for index, row in dfmerged.iterrows():
    if row['district_x'] not in districtlst:
        districtlst.append(row['district_x'])


dfdistrictlevelmerged = pd.DataFrame(districtlst, columns=['district'])

def district_score():
    score_lst = []
    score = 0
    current_district = dfmerged.iloc[0]['district_x']
    for index, row in dfmerged.iterrows():
        if row['district_x'] == current_district:
            score += int(row['score'])
        else:
            #print(score)
            score_lst.append(score)
            current_district = row['district_x']
            score = 0
            score += int(row['score'])
    return score_lst

score_lst = district_score()

#score_lst.append(100)

score_lst.append(691)

dfdistrictlevelmerged['scores'] = score_lst

# %%
def number_of_schools():
    lst_schools = []
    count = 1
    current_district = dfmerged.iloc[0]['district_x']
    for index, row in dfmerged.iterrows():
        #print(current_district)
        if row['district_x'] == current_district:
            count += 1
        else:
            current_district = row['district_x']
            lst_schools.append(count)
            count = 1
    return lst_schools

school_count_lst = number_of_schools()

school_count_lst.pop(0)

school_count_lst = [1] + school_count_lst

school_count_lst.append(2)
print(len(districtlst))

print(len(school_count_lst))

dfdistrictlevelmerged['school count'] = school_count_lst
# Out:
# 369
# 369

# %%
def number_of_levels_2012():
    level_lst = []
    count = 0
    current_district = dfmerged.iloc[0]['district_x']
    for index, row in dfmerged.iterrows():
        if row['district_x'] == current_district:
            count += row['level_2012']
        else:
            current_district = row['district_x']
            level_lst.append(count)
            count = 0
            count += row['level_2012']
    return level_lst

level_lst_2012 = number_of_levels_2012()

level_lst_2012.append(2)  

print(len(level_lst_2012))

dfdistrictlevelmerged['levels 2012'] = level_lst_2012
# Out:
# 369

# %%
def number_of_levels_2016():
    level_lst = []
    count = 0
    current_district = dfmerged.iloc[0]['district_x']
    for index, row in dfmerged.iterrows():
        if row['district_x'] == current_district:
            count += row['level_2016']
        else:
            current_district = row['district_x']
            level_lst.append(count)
            count = 0
            count += row['level_2016']
    return level_lst

level_lst_2016 = number_of_levels_2016()

level_lst_2016.append(2)  

print(len(level_lst_2016))

dfdistrictlevelmerged['levels 2016'] = level_lst_2016
# Out:
# 369

# %%
def number_of_students_2012():
    student_lst = []
    count = 0
    current_district = dfmerged.iloc[0]['district_x']
    for index, row in dfmerged.iterrows():
        if row['district_x'] == current_district:
            count += int(row['student_count'])
        else:
            current_district = row['district_x']
            student_lst.append(count)
            count = 0
            count += int(row['student_count'])
    return student_lst

students_2012_lst = number_of_students_2012()

students_2012_lst.append(2)  

print(len(students_2012_lst))

dfdistrictlevelmerged['students 2012'] = students_2012_lst
# Out:
# 369

# %%
def number_of_students_2016():
    student_lst = []
    count = 0
    current_district = dfmerged.iloc[0]['district_x']
    for index, row in dfmerged.iterrows():
        if row['district_x'] == current_district:
            count += int(row['student_count'])
        else:
            current_district = row['district_x']
            student_lst.append(count)
            count = 0
            count += int(row['student_count'])
    return student_lst

students_2016_lst = number_of_students_2016()

students_2016_lst.append(2)  

print(len(students_2016_lst))

dfdistrictlevelmerged['students 2016'] = students_2016_lst
# Out:
# 369

# %%
dfdistrictlevelmerged
# Out:
#                                               district  scores  school count  \
# 0        Abby Kelley Foster Charter Public (District)    -1426             1
# 1                                            Abington      183             3
# 2    Academy Of the Pacific Rim Charter Public (Dis...    -493             1
# 3                                    Acton-Boxborough      939             2
# 4                                            Acushnet     -540             2
# 5                                      Adams-Cheshire     -751             3
# 6    Advanced Math and Science Academy Charter (Dis...    -969             1
# 7                                              Agawam    -1607             7
# 8                                            Amesbury    -1613             4
# 9                                             Amherst        0             3
# 10                                     Amherst-Pelham      595             2
# 11                                            Andover    -1785             9
# 12                                          Arlington     1515             9
# 13                             Ashburnham-Westminster     -303             4
# 14                                            Ashland        0             3
# 15       Assabet Valley Regional Vocational Technical    -1010             1
# 16                                    Athol-Royalston     -690             5
# 17                        Atlantis Charter (District)     -753             1
# 18                                          Attleboro     -875             9
# 19                                             Auburn     -749             2
# 20                                               Avon        0             2
# 21                       Ayer Shirley School District      544             3
# 22                                         Barnstable      338             4
# 23   Barnstable Community Horace Mann Charter Publi...       0             1
# 24                                            Bedford        0             3
# 25                                        Belchertown     -941             4
# 26                                         Bellingham      452             4
# 27                                            Belmont     1259             6
# 28        Benjamin Banneker Charter Public (District)        0             1
# 29   Benjamin Franklin Classical Charter Public (Di...       0             1
# ..                                                 ...     ...           ...
# 339                                           Waltham    -1802             9
# 340                                              Ware      156             3
# 341                                           Wareham     -607             3
# 342                                         Watertown      765             5
# 343                                           Wayland      583             4
# 344                                           Webster        0             1
# 345                                         Wellesley     1794             9
# 346                                         Wellfleet        0             1
# 347                                     West Boylston        0             2
# 348                                  West Bridgewater        0             3
# 349                                  West Springfield      129             7
# 350                                       Westborough      851             6
# 351                                         Westfield      357            11
# 352                                          Westford      812             6
# 353                                       Westhampton        0             1
# 354                                            Weston     -202             5
# 355                                          Westport        0             3
# 356                                          Westwood     1063             7
# 357                                          Weymouth      732            11
# 358                                           Whately        0             1
# 359                                    Whitman-Hanson     2166             6
# 360            Whittier Regional Vocational Technical    -1223             1
# 361                                      Williamstown      446             1
# 362                                        Wilmington     -597             6
# 363                                        Winchendon        0             1
# 364                                        Winchester     -572             7
# 365                                          Winthrop     -551             2
# 366                                            Woburn     -432            11
# 367                                         Worcester     2033            44
# 368                                          Wrentham      691             2
#
#      levels 2012  levels 2016  students 2016  students 2012
# 0              1            2           1426           1426
# 1              5            5           1159           1159
# 2              1            2            493            493
# 3              3            2           2928           2928
# 4              3            4           1003           1003
# 5              7            8           1482           1482
# 6              1            2            969            969
# 7             12           14           3982           3982
# 8              5            8           2351           2351
# 9              6            6           1226           1226
# 10             5            5           1559           1559
# 11            14           15           5986           5986
# 12            14           14           4838           4838
# 13             7            7           2038           2038
# 14             4            4           1916           1916
# 15             1            2           1010           1010
# 16            13           16           1353           1353
# 17             1            2            753            753
# 18            13           12           5745           5745
# 19             3            4           1334           1334
# 20             3            3            770            770
# 21             6            5           1260           1260
# 22             6            5           2902           2902
# 23             2            2            284            284
# 24             5            5           2030           2030
# 25             5            7           2308           2308
# 26             8            7           2109           2109
# 27             7            6           4088           4088
# 28             1            1            351            351
# 29             1            1            446            446
# ..           ...          ...            ...            ...
# 339           19           19           5053           5053
# 340            7            7           1336           1336
# 341            7            8           1968           1968
# 342           11           10           2745           2745
# 343            6            5           2519           2519
# 344            3            3            799            799
# 345           13           11           4993           4993
# 346            1            1            145            145
# 347            4            4            953            953
# 348            5            5           1220           1220
# 349           14           11           3564           3564
# 350            7            6           3577           3577
# 351           27           25           5756           5756
# 352            8            6           4159           4159
# 353            1            1            150            150
# 354            6            6           2406           2406
# 355            6            6           1489           1489
# 356            9            7           3149           3149
# 357           20           21           6660           6660
# 358            2            2            150            150
# 359           12            9           3833           3833
# 360            1            2           1223           1223
# 361            2            1            446            446
# 362           10           10           3221           3221
# 363            3            3            330            330
# 364            8            8           4409           4409
# 365            3            4           1014           1014
# 366           19           21           4829           4829
# 367          107          101          23805          23805
# 368            2            2              2              2
#
# [369 rows x 7 columns]

# %%
dfdistrictlevel['school count'] = school_count_lst

dfdistrictlevel

# %%
# get number of schools at each level

def school_level_counts_2012():
    school_count_1 = []
    school_count_2 = []
    school_count_3 = []
    school_count_4 = []
    school_count_5 = []
    count1 = 0
    count2 = 0
    count3 = 0
    count4 = 0
    count5 = 0
    
    current_district = df.iloc[0]['district']
    for index, row in df.iterrows():
        if row['district'] == current_district:
            
            if row['level_2012'] == 1:
                count1 += 1
            elif row['level_2012'] == 2:
                count2 += 1
            elif row['level_2012'] == 3:
                count3 += 1
            elif row['level_2012'] == 4:
                count4 += 1
            elif row['level_2012'] == 5:
                count5 += 1
            

        else:
            if index == 0:
                if row['level_2012'] == 1:
                    count1 += 1
                elif row['level_2012'] == 2:
                    count2 += 1
                elif row['level_2012'] == 3:
                    count3 += 1
                elif row['level_2012'] == 4:
                    count4 += 1
                elif row['level_2012'] == 5:
                    count5 += 1
                current_district = row['district']
            else:
                school_count_1.append(count1)
                school_count_2.append(count2)
                school_count_3.append(count3)
                school_count_4.append(count4)
                school_count_5.append(count5)
                count1 = 0
                count2 = 0
                count3 = 0
                count4 = 0
                count5 = 0
                if row['level_2012'] == 1:
                    count1 += 1
                elif row['level_2012'] == 2:
                    count2 += 1
                elif row['level_2012'] == 3:
                    count3 += 1
                elif row['level_2012'] == 4:
                    count4 += 1
                elif row['level_2012'] == 5:
                    count5 += 1
                current_district = row['district']
    school_count_1.append(0)
    school_count_2.append(2)
    school_count_3.append(0)
    school_count_4.append(0)
    school_count_5.append(0)
    return school_count_1, school_count_2, school_count_3, school_count_4, school_count_5 

level_1_schools_2012, level_2_schools_2012, level_3_schools_2012, level_4_schools_2012, \
level_5_schools_2012 = school_level_counts_2012()

print(len(level_2_schools_2012))

#schools_above_3_2012_lst.pop(0)

#schools_above_3_2012_lst.append(0)

dfdistrictlevel['level 1 2012'] = level_1_schools_2012
dfdistrictlevel['level 2 2012'] = level_2_schools_2012
dfdistrictlevel['level 3 2012'] = level_3_schools_2012
dfdistrictlevel['level 4 2012'] = level_4_schools_2012
dfdistrictlevel['level 5 2012'] = level_5_schools_2012

# %%
# get number of schools level 3 or below at 2012 and at 2016

def school_level_counts_2016():
    school_count_1 = []
    school_count_2 = []
    school_count_3 = []
    school_count_4 = []
    school_count_5 = []
    count1 = 0
    count2 = 0
    count3 = 0
    count4 = 0
    count5 = 0
    
    current_district = df.iloc[0]['district']
    for index, row in df.iterrows():
        if row['district'] == current_district:
            
            if row['level_2016'] == 1:
                count1 += 1
            elif row['level_2016'] == 2:
                count2 += 1
            elif row['level_2016'] == 3:
                count3 += 1
            elif row['level_2016'] == 4:
                count4 += 1
            elif row['level_2016'] == 5:
                count5 += 1
            

        else:
            if index == 0:
                if row['level_2016'] == 1:
                    count1 += 1
                elif row['level_2016'] == 2:
                    count2 += 1
                elif row['level_2016'] == 3:
                    count3 += 1
                elif row['level_2016'] == 4:
                    count4 += 1
                elif row['level_2016'] == 5:
                    count5 += 1
                current_district = row['district']
            else:
                school_count_1.append(count1)
                school_count_2.append(count2)
                school_count_3.append(count3)
                school_count_4.append(count4)
                school_count_5.append(count5)
                count1 = 0
                count2 = 0
                count3 = 0
                count4 = 0
                count5 = 0
                if row['level_2016'] == 1:
                    count1 += 1
                elif row['level_2016'] == 2:
                    count2 += 1
                elif row['level_2016'] == 3:
                    count3 += 1
                elif row['level_2016'] == 4:
                    count4 += 1
                elif row['level_2016'] == 5:
                    count5 += 1
                current_district = row['district']
    school_count_1.append(1)
    school_count_2.append(1)
    school_count_3.append(0)
    school_count_4.append(0)
    school_count_5.append(0)
    return school_count_1, school_count_2, school_count_3, school_count_4, school_count_5 

level_1_schools_2016, level_2_schools_2016, level_3_schools_2016, level_4_schools_2016, \
level_5_schools_2016 = school_level_counts_2016()

print(len(level_2_schools_2016))

#schools_above_3_2016_lst.pop(0)

#schools_above_3_2016_lst.append(0)

dfdistrictlevel['level 1 2016'] = level_1_schools_2016
dfdistrictlevel['level 2 2016'] = level_2_schools_2016
dfdistrictlevel['level 3 2016'] = level_3_schools_2016
dfdistrictlevel['level 4 2016'] = level_4_schools_2016
dfdistrictlevel['level 5 2016'] = level_5_schools_2016

# %%
# gets the delta difference in school level between 2016 and 2012

deltalst = []
for index, row in dfdistrictlevel.iterrows():
    deltalst.append( row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']- (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) )
    
dfdistrictlevel['change in level'] = deltalst

# %%
writer = pd.ExcelWriter('dflevels.xlsx')
dfdistrictlevel.to_excel(writer,'Sheet1')
writer.save()

# %%
# new dataframe that uses percentage and removes districts with 4 or less schools

dfleveldelta = dfdistrictlevel[dfdistrictlevel['school count'] > 12]

dfleveldelta = dfleveldelta[dfleveldelta['change in level'] != 0]

#dfleveldelta['% schools higher than 3'] = dfleveldelta['% schools higher than 3'].apply(lambda x: round(x)) 

writer = pd.ExcelWriter('dflevels_schools_size_12.xlsx')
dfleveldelta.to_excel(writer,'Sheet1')
writer.save()

del dfleveldelta['change in level']
dfleveldelta

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'] , ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='r', alpha=0.4)

rects2 = ax.bar(ind + width, x2, width, color='b', alpha=0.4)

# add some text for labels, title and axes ticks
ax.set_ylabel('number of schools level 3 or higher')
ax.set_xlabel('district')
ax.set_title('Net Number of Schools Level 3 or Higher 2012 vs. 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,60])


plt.savefig('schools_level_3or_higher_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'] , ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) / row['school count'] )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) / row['school count'] )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='blue', alpha=0.3)
rects1[6].set_color('red')

rects2 = ax.bar(ind + width, x2, width, color='lightgreen', alpha=0.4)
rects2[6].set_color('cyan')

# add some text for labels, title and axes ticks
ax.set_ylabel('percentage of level 3 or higher')
ax.set_xlabel('district')
ax.set_title('Percentage of Schools Level 3 or Higher out of Total Schools 2012 vs. 2016')
ax.set_xticks(ind + width -1 / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,1])


#plt.savefig('percentage_schools_level_3or_higher_out_of_total_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'], ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 3 2012'])  )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 3 2016'])  )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='blue', alpha=0.3)
rects1[6].set_color('red')

rects2 = ax.bar(ind + width, x2, width, color='lightgreen', alpha=0.4)
rects2[6].set_color('cyan')

# add some text for labels, title and axes ticks
ax.set_ylabel('number of level 3 schools')
ax.set_xlabel('district')
ax.set_title('number of level 3 schools 2012 vs. 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,50])


#plt.savefig('schools_level_3_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'], ascending=False)

N = len(dfplot)

width = 0.35       # the width of the bars


x1 = []
for index, row in dfplot.iterrows():
    x1.append( (row['level 4 2012']) + (row['level 5 2012'])  )

x2 = []
for index, row in dfplot.iterrows():
    x2.append( (row['level 4 2016']) + (row['level 5 2016'])  )

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x1, width, color='blue', alpha=0.3)
rects1[6].set_color('red')

rects2 = ax.bar(ind + width, x2, width, color='lightgreen', alpha=0.4)
rects2[6].set_color('cyan')

# add some text for labels, title and axes ticks
ax.set_ylabel('number of level 4 and 5 schools')
ax.set_xlabel('district')
ax.set_title('Number of Level 4 and 5 Schools 2012 vs. 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])

ax.legend((rects1[0], rects2[0]), ('2012', '2016'))

plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')
        

plt.ylim([0,13])


plt.savefig('schools_level_4-5_2012vs2016.png', dpi=600, bbox_inches='tight')


plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

dfplot = dfleveldelta.sort_values(['school count'], ascending=False)

N = len(dfplot)

x = []
for index, row in dfplot.iterrows():
    #x.append(  (( row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) -  (row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016'])) / row['school count'] )
    x.append(  1 - ((row['level 3 2016'] + row['level 4 2016'] + row['level 5 2016']) /  ( row['level 3 2012'] + row['level 4 2012'] + row['level 5 2012']) ))
    

width = 0.95       # the width of the bars

ind = np.arange(N)
fig, ax = plt.subplots()

rects1 = ax.bar(ind, x, width, color='blue', alpha=0.3)
rects1[6].set_color('red')


# add some text for labels, title and axes ticks
ax.set_ylabel('Percentage of Schools')
ax.set_xlabel('district')
ax.set_title('Percentage of Schools that were level 3 or higher in 2012 and are level 2 or lower in 2016')
ax.set_xticks(ind + width / len(dfplot) )
ax.set_xticklabels(dfplot['district'])
plt.setp(ax.get_xticklabels(), rotation=35, horizontalalignment='right')

plt.ylim([0,.55])


plt.savefig('percent_schools_rose_from_lvl3_barchart.png', dpi=600, bbox_inches='tight')
plt.show()

# %%
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt


x = dfplot['number of schools at level 3 or higher 2012']
y = dfplot['number of schools at level 3 or higher 2016']

colors = np.random.rand(20)

plt.scatter(x, y, s=(dfplot['% schools higher than 3'].apply(lambda x: x * 1000)), c='maroon', alpha=0.5)

plt.show()
